# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('Wine_data.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
for i in df.columns:
    print(df[i].mean(), df[i].median(), df[i].quantile([0.25,0.50,0.75,1]))
# Out:
# 6.854787668436075 6.8 0.25     6.3
# 0.50     6.8
# 0.75     7.3
# 1.00    14.2
# Name: fixed acidity, dtype: float64
# 0.27824111882401087 0.26 0.25    0.21
# 0.50    0.26
# 0.75    0.32
# 1.00    1.10
# Name: volatile acidity, dtype: float64
# 0.33419150673743736 0.32 0.25    0.27
# 0.50    0.32
# 0.75    0.39
# 1.00    1.66
# Name: citric acid, dtype: float64
# 6.391414863209486 5.2 0.25     1.7
# 0.50     5.2
# 0.75     9.9
# 1.00    65.8
# Name: residual sugar, dtype: float64
# 0.0457723560636995 0.043 0.25    0.036
# 0.50    0.043
# 0.75    0.050
# 1.00    0.346
# Name: chlorides, dtype: float64
# 35.30808493262556 34.0 0.25     23.0
# 0.50     34.0
# 0.75     46.0
# 1.00    289.0
# Name: free sulfur dioxide, dtype: float64
# 138.36065741118824 134.0 0.25    108.0
# 0.50    134.0
# 0.75    167.0
# 1.00    440.0
# Name: total sulfur dioxide, dtype: float64
# 0.9940273764801896 0.99374 0.25    0.991723
# 0.50    0.993740
# 0.75    0.996100
# 1.00    1.038980
# ...

# %%
df.quantile([0.25,0.50,0.75,1])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0.25            6.3              0.21         0.27             1.7      0.036
# 0.50            6.8              0.26         0.32             5.2      0.043
# 0.75            7.3              0.32         0.39             9.9      0.050
# 1.00           14.2              1.10         1.66            65.8      0.346
#
#       free sulfur dioxide  total sulfur dioxide   density    pH  sulphates  \
# 0.25                 23.0                 108.0  0.991723  3.09       0.41
# 0.50                 34.0                 134.0  0.993740  3.18       0.47
# 0.75                 46.0                 167.0  0.996100  3.28       0.55
# 1.00                289.0                 440.0  1.038980  3.82       1.08
#
#       alcohol  quality
# 0.25      9.5      5.0
# 0.50     10.4      6.0
# 0.75     11.4      6.0
# 1.00     14.2      9.0

# %%
df.mean()
# Out:
# fixed acidity             6.854788
# volatile acidity          0.278241
# citric acid               0.334192
# residual sugar            6.391415
# chlorides                 0.045772
# free sulfur dioxide      35.308085
# total sulfur dioxide    138.360657
# density                   0.994027
# pH                        3.188267
# sulphates                 0.489847
# alcohol                  10.514267
# quality                   5.877909
# dtype: float64

# %%
df.median()
# Out:
# fixed acidity             6.80000
# volatile acidity          0.26000
# citric acid               0.32000
# residual sugar            5.20000
# chlorides                 0.04300
# free sulfur dioxide      34.00000
# total sulfur dioxide    134.00000
# density                   0.99374
# pH                        3.18000
# sulphates                 0.47000
# alcohol                  10.40000
# quality                   6.00000
# dtype: float64

# %%
# RANGE
df.max() - df.min()
# Out:
# fixed acidity            10.40000
# volatile acidity          1.02000
# citric acid               1.66000
# residual sugar           65.20000
# chlorides                 0.33700
# free sulfur dioxide     287.00000
# total sulfur dioxide    431.00000
# density                   0.05187
# pH                        1.10000
# sulphates                 0.86000
# alcohol                   6.20000
# quality                   6.00000
# dtype: float64

# %%
df.var()
# Out:
# fixed acidity              0.712114
# volatile acidity           0.010160
# citric acid                0.014646
# residual sugar            25.725770
# chlorides                  0.000477
# free sulfur dioxide      289.242720
# total sulfur dioxide    1806.085491
# density                    0.000009
# pH                         0.022801
# sulphates                  0.013025
# alcohol                    1.514427
# quality                    0.784356
# dtype: float64

# %%
df.std()
# Out:
# fixed acidity            0.843868
# volatile acidity         0.100795
# citric acid              0.121020
# residual sugar           5.072058
# chlorides                0.021848
# free sulfur dioxide     17.007137
# total sulfur dioxide    42.498065
# density                  0.002991
# pH                       0.151001
# sulphates                0.114126
# alcohol                  1.230621
# quality                  0.885639
# dtype: float64

# %%
df.mad()
# Out:
# fixed acidity            0.644923
# volatile acidity         0.073803
# citric acid              0.086411
# residual sugar           4.227788
# chlorides                0.011462
# free sulfur dioxide     13.149156
# total sulfur dioxide    34.282442
# density                  0.002447
# pH                       0.118204
# sulphates                0.087504
# alcohol                  1.034213
# quality                  0.670793
# dtype: float64

# %%
df.cov()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              0.712114         -0.001931     0.029533
# volatile acidity          -0.001931          0.010160    -0.001823
# citric acid                0.029533         -0.001823     0.014646
# residual sugar             0.381022          0.032865     0.057829
# chlorides                  0.000426          0.000155     0.000302
# free sulfur dioxide       -0.708919         -0.166300     0.193630
# total sulfur dioxide       3.266013          0.382354     0.622989
# density                    0.000670          0.000008     0.000054
# pH                        -0.054265         -0.000486    -0.002992
# sulphates                 -0.001651         -0.000411     0.000861
# alcohol                   -0.125533          0.008400    -0.011278
# quality                   -0.084947         -0.017382    -0.000987
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# Higer covariance-
#
# Residual sugar and free sulfur dioxide
# Residual sugar and total sulfur dioxide
# total sulfur dioxide and free sulfur dioxide
#
# Lesser (negative) covariance-
#
# total sulfur dioxide and alcohol
# free sulfur dioxide and alcohol

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# Correlation;
#
# highest correlation exists between - residual sugar and density; which makes sense- as the sugar increases, wine becomes more viscous, thick. The glucose increase also makes it settling rate higher.
#
# Citric acis and fixed acidity share positive correlation- common sense. no rocket science there.
#
# Desnity and chlorides share positive correlation- which makes sense as chlorides are generally having high density and a very low boiling point.
#
# Negative correlations:
# Density and alcohol share negative correlation as they have no such relation.
# similar with total sulfur dioxide and alcohol.
