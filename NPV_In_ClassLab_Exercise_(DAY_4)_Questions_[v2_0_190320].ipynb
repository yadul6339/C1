# %% [markdown]
# <a href="https://colab.research.google.com/github/zerryberry/C1/blob/master/NPV_In_ClassLab_Exercise_(DAY_4)_Questions_%5Bv2_0_190320%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                   <b> Inclass - Lab <br> (Day 4) </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ##  Table of Content
#
# 1. **[Plots using Library Matplotlib ](#matplotlib)**
# 2. **[Plots using Library Seaborn ](#seaborn)**

# %% [markdown]
# ### Let us import the required libraries.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='matplotlib'></a>
# ## 1. Plots using Library Matplotlib

# %% [markdown]
# ### a. Scatter Plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Plot a scatter plot for the following data. Also add title and axis names</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             bmi = (18, 34, 54, 45, 45, 45, 23, 23, 54)
#             medical_claim = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %%
bmi = (18, 34, 54, 45, 45, 45, 23, 23, 54)
medical_claim = (145, 456, 764, 234, 156, 786, 345, 455, 675)
mlt.scatter(bmi, medical_claim)
mlt.xlabel('BMI')
mlt.ylabel('Medical_claims')
mlt.title('BMI vs medical claims')
# Out:
# Text(0.5, 1.0, 'BMI vs medical claims')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Write a code to get the following output </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <img src="cos_curve.png" width = '500' >

# %%
x = np.arange(0.1,12,0.1)
y = np.sin(x)
z= np.cos(x)
plt.plot(x,y)
plt.plot(x,z)
plt.xlabel('x values from 0 to 12')
plt.ylabel('sin(x) and cos(x)')
plt.title('Plot of sin and cos from 0 to 12')
plt.legend(['sin(x)', 'cos(x)']) 
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 3. Plot cosine curve and exponential curve for natural numbers from 0.1 to 20, in the same plot (get the following output)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <img src="dual_axis.png" width ='500' >

# %%
import math
import numpy as np

# %%
v= list(map(int, [i for i in np.arange(0.1,21,1)]))
coss= np.cos(v)
exp= np.exp(v)
fig, axes= plt.subplots(1,2, figsize=(8,3), dpi=100)
axes[0].plot(v, coss)
axes[1].plot(v, exp)

# %%
# or on the same axis:

v= list(map(int, [i for i in np.arange(0.1, 21, 1)]))
cos= np.cos(v)
exp= np.exp(v)
fig, axes= plt.subplots(1,1, figsize=(8,3), dpi=100)
axes.plot(v,cos, color= 'r')
axes.set_ylabel('cos values')
axes.set_xlabel('numbers')

ax1= axes.twinx()
axes.set_ylabel('exponential values')
ax1.plot(v,exp, color= 'b')

plt.show()

# %% [markdown]
# ### b. Barplots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 5. The exports and imports (in billion dollars) is given for a country from 2001 to 2005. Draw a barplot for the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Year</th>
#   <th>Import</th>
#   <th>Export</th>
#   </tr>
#   <tr>
#   <td>2001</td>
#   <td>54.4</td>
#   <td>42.5 </td>
#   </tr>
#   <tr>
#   <td>2002</td>
#   <td>53.8</td>
#   <td>44.5</td>
#   </tr>
#   <tr>
#   <td>2003</td>
#   <td>61.6</td>
#   <td>48.3</td>
#   </tr>
#   <tr>
#   <td>2004</td>
#   <td>74.15</td>
#   <td>57.24</td>
#   </tr>
#   <tr>
#   <td>2005</td>
#   <td>89.33</td>
#   <td>69.18</td>
#   </tr>
# </table>

# %%
import pandas as pd
y= [i for i in range(2001,2006)]
im= [54.4, 53.8,61.6,74.15,89.33]
iex= [42.5,44.5,48.3,57.24,69.18]
df= pd.DataFrame(zip(y,im,iex), columns= ['Year', 'Import', 'Export'])
df
# Out:
#    Year  Import  Export
# 0  2001   54.40   42.50
# 1  2002   53.80   44.50
# 2  2003   61.60   48.30
# 3  2004   74.15   57.24
# 4  2005   89.33   69.18

# %%
df.plot(x= 'Year', y= ['Import', 'Export'], kind= 'bar', title= 'Import and Export', xlabel= 'Year', ylabel= 'in Millions')

# %% [markdown]
# ### c. Pie plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 6. Plot a pie chart for the following data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#         prices = [50, 25, 50, 20]
#         labels = ['Apple', 'Orange','Banana', 'Mango']

# %%
prices = [50, 25, 50, 20]
labels = ['Apple', 'Orange','Banana', 'Mango']
dg= pd.Series(prices, labels)
plt.pie(dg, labels=labels, autopct=(lambda x: '{:.0f}'.format((x/100)*sum(prices))), colors=['red', 'orange', 'yellow', 'green'], shadow= True)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 7. Following is the information release after the Indian budget is declared. Plot a pie chart for it
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Income Form </th>
#   <th>Amount (in paise)</th>
#   </tr>
#   <tr>
#   <td>Corporation Tax</td>
#   <td>21</td>
#   </tr>
#   <tr>
#   <td>Income Tax</td>
#   <td>16</td>
#   </tr>
#   <tr>
#   <td>Customs</td>
#   <td>4</td>
#   </tr>
#   <tr>
#   <td>Union Excise Duties</td>
#   <td>8</td>
# </tr>
#   <tr>
#   <td>GST & Other Taxes</td>
#   <td>19</td>
# </tr>
# <tr>
#   <td>Non-Tax Revenue</td>
#   <td>9</td>
#   </tr>
#   <tr>
#   <td>Non-Debt Capital Receipts</td>
#   <td>3</td>
# </tr>
#   <tr>
#   <td>Borrowings and Other Liabilities</td>
#   <td>20</td>
#   </tr>
# </table>

# %%
import pandas as pd
inc= ['Corporation Tax', 'Income Tax', 'Customs', 'Union Excise Duties', 'GST & Other Taxes', 'Non-Tax Revenue', 'Non-Debt Capital Receipts', 'Borrowings and Other Liabilities']
am= [21,16,4,8,19,9,3,20]
d= pd.Series(am, inc)
d
# Out:
# Corporation Tax                     21
# Income Tax                          16
# Customs                              4
# Union Excise Duties                  8
# GST & Other Taxes                   19
# Non-Tax Revenue                      9
# Non-Debt Capital Receipts            3
# Borrowings and Other Liabilities    20
# dtype: int64

# %%
plt.pie(d, labels=inc, autopct=(lambda x: '{:.0f}'.format((x/100)*sum(am))))
circle = plt.Circle(xy=(0,0), radius=0.4, color='white')
ax= plt.gca()
ax.add_artist(circle)
plt.show()

# %% [markdown]
# ### d. Line plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 8. Create a tuple of numbers 12, 34, 54, 45, 45, 45, 23, 23, 54 and plot a simple line plot
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
a= (12, 34, 54, 45, 45, 45, 23, 23, 54)
plt.plot(a)
plt.ylabel('random tuple')
plt.grid('white')
plt.show()

# %%
import seaborn as sns
df_flights=sns.load_dataset('flights')
df_flights.head()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 9. Import the 'Returns.csv'. Plot a multiple line plot for the returns of each company
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
d[d.columns[1:]]
# Out:
#          TCS  HDFCBANK  JINDALSTEL  TATAMOTORS      INFY  BOSCHLTD
# 0   1.439254 -0.425880   -0.496099    0.589743 -0.212106 -1.882246
# 1   1.382147 -1.650396   -0.421246    0.962322 -0.025425 -2.474510
# 2   0.921320 -0.208786   -0.452879    0.776448 -0.561877  1.556494
# 3  -0.572887 -0.315136   -0.364378    0.563103 -0.928679 -1.202984
# 4   1.275049  0.098216   -0.104096   -0.483990 -0.108262 -2.018111
# 5  -0.328832  0.632894    0.325862    0.003768 -0.589602  2.494628
# 6  -0.146341  0.411697   -0.538937    0.117627  0.822381 -3.708947
# 7   1.058437 -1.158514    0.423811   -0.370031  0.361715 -1.617864
# 8  -0.111080 -1.159860    0.209816    0.174847  0.624075  2.360908
# 9  -0.038881 -0.689510    0.213396    0.135003  0.366363  5.610539
# 10 -0.322363 -1.052269   -0.101423   -0.039998 -0.160511  0.135336
# 11 -0.665766 -2.223733    0.076849   -0.119925  0.250447  1.918317
# 12 -0.704620 -0.656223    0.225169   -0.028262  0.259971 -2.093713
# ...

# %%
#import matplotlib.pyplot as plt
d= pd.read_csv('Returns.csv')
fig, ax= plt.subplots(1, figsize= (9,5))
ax.plot(d[d.columns[1:]])
ax.legend(d.columns)
plt.xlabel('indexes')
plt.ylabel('Returns')
plt.title('Returns of Companies')
plt.show()

# %% [markdown]
# <a id='seaborn'></a>
# ## 2. Plots using Library Seaborn

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 10. Plot a  strip plot using inbuilt data-set 'iris' given in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import seaborn as sns
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig, ax= plt.subplots(2,2, figsize=(8,6))
sns.stripplot(x='species', y= 'sepal_length', data= iris, ax=ax[0,0])
sns.stripplot(x='species', y= 'sepal_width', data= iris, ax=ax[0,1])
sns.stripplot(x='species', y= 'petal_length', data= iris, ax=ax[1,0])
sns.stripplot(x='species', y= 'petal_width', data= iris, ax=ax[1,1])

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 11. Import the dataset age_height.csv. Plot a heat map for the correlation matrix
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df= pd.read_csv('age_height.csv')
df.corr()
# Out:
#                      Age  Weight (in kg)  Height (in m)
# Age             1.000000        0.030012      -0.169180
# Weight (in kg)  0.030012        1.000000      -0.230432
# Height (in m)  -0.169180       -0.230432       1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 13a. Using the following data, plot a scatter plot with  the function available in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
#             y = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %%
x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
y = (145, 456, 764, 234, 156, 786, 345, 455, 675)
sns.set_theme(context='notebook', style='darkgrid')
sns.scatterplot(x=x, y=y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 13b. Using the data generated in question 3, plot a scatter plot with the function available in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import math
v= [i for i in range(720)]
d= list(map(lambda x: x*math.pi/180, v))
sns.scatterplot(x= v, y= np.cos(d))

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 14. Using the 'diamonds' data available in the library seaborn, consider the price for the type of cut. Display the data using the following plots:
#                         <ol>
#                             <li> Multiple boxplot</li>
#                             <li> Violin Plot </li>
#                             <li> Boxen Plot </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
diamonds=sns.load_dataset('diamonds')
diamonds.head()
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.median()
# Out:
# carat       0.70
# depth      61.80
# table      57.00
# price    2401.00
# x           5.70
# y           5.71
# z           3.53
# dtype: float64

# %%
#a
diamonds=sns.load_dataset('diamonds')
diamonds.head()
sns.boxplot(x='cut', y= 'price', data=diamonds)

# %%
#b

sns.violinplot(x='cut', y= 'price', data=diamonds)

# %%
sns.boxenplot(x='cut', y= 'price', data=diamonds)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 15. Generate random number form normal distribution, plot the following:
#                         <ol>
#                             <li> Histogram</li>
#                             <li> Histogram with frequency curve </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
v= list(map(int, np.random.randn(1000)))
sns.histplot(v)

# %%
#b

sns.distplot(v)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import pandas as pd
d= pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds41.csv')
d
